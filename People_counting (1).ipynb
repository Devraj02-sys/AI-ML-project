# %%
# !pip install -q ultralytics opencv-python

import cv2
import numpy as np
from ultralytics import YOLO
from google.colab import files
import os
import time

video_path = "/content/853889-hd_1920_1080_25fps.mp4"

class CentroidTracker:
    def __init__(self, maxDisappeared=40, maxDistance=50):
        self.nextObjectID = 0
        self.objects = dict()        # objectID -> centroid (x,y)
        self.rects = dict()          # objectID -> bounding box (startX, startY, endX, endY)
        self.disappeared = dict()    # objectID -> frames disappeared
        self.maxDisappeared = maxDisappeared
        self.maxDistance = maxDistance

    def register(self, centroid, rect):
        self.objects[self.nextObjectID] = centroid
        self.rects[self.nextObjectID] = rect
        self.disappeared[self.nextObjectID] = 0
        self.nextObjectID += 1

    def deregister(self, objectID):
        del self.objects[objectID]
        del self.rects[objectID]
        del self.disappeared[objectID]

    def update(self, rects):
        # rects: list of (startX, startY, endX, endY)
        if len(rects) == 0:
            # mark all existing objects as disappeared
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)
            return self.objects, self.rects

        # compute input centroids
        inputCentroids = np.zeros((len(rects), 2), dtype="int")
        for (i, (startX, startY, endX, endY)) in enumerate(rects):
            cX = int((startX + endX) / 2.0)
            cY = int((startY + endY) / 2.0)
            inputCentroids[i] = (cX, cY)

        # if no existing objects, register all
        if len(self.objects) == 0:
            for i in range(len(inputCentroids)):
                self.register(inputCentroids[i], rects[i])
        else:
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())

            # distance matrix between object centroids and input centroids
            D = np.linalg.norm(np.array(objectCentroids)[:, None] - inputCentroids[None, :], axis=2)

            # greedy match: sort rows by their minimal distance
            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]

            usedRows = set()
            usedCols = set()

            for (row, col) in zip(rows, cols):
                if row in usedRows or col in usedCols:
                    continue
                if D[row, col] > self.maxDistance:
                    continue
                objectID = objectIDs[row]
                self.objects[objectID] = inputCentroids[col]
                self.rects[objectID] = rects[col]
                self.disappeared[objectID] = 0
                usedRows.add(row)
                usedCols.add(col)

            # find unmatched
            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            # if more existing objects than inputs -> increment disappeared
            if D.shape[0] >= D.shape[1]:
                for row in unusedRows:
                    objectID = objectIDs[row]
                    self.disappeared[objectID] += 1
                    if self.disappeared[objectID] > self.maxDisappeared:
                        self.deregister(objectID)
            else:
                # new objects appeared -> register them
                for col in unusedCols:
                    self.register(inputCentroids[col], rects[col])

        return self.objects, self.rects

class TrackableObject:
    def __init__(self, objectID, centroid):
        self.objectID = objectID
        self.centroids = [centroid]
        self.counted = False

print("Loading YOLOv8 model (may take ~30s)...")
model = YOLO("yolov8n.pt")  # downloads if needed

ct = CentroidTracker(maxDisappeared=40, maxDistance=60)
trackableObjects = dict()
totalCount = 0

# open video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise SystemExit("❌ Error: Could not open the input video. Check path or try re-downloading.")

W = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
H = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fps = fps if fps and fps > 0 else 20.0

# output writer (MP4)
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out_path = "people_counting.mp4"
out = cv2.VideoWriter(out_path, fourcc, fps, (W, H))

# horizontal counting line (y-coordinate)
line_y = H // 2
line_offset = 10  # thickness offset for text placement

print(f"Video opened: {video_path}  (W,H) = ({W},{H}), fps={fps}")
start = time.time()

# ======= Step 5: Process frames =======
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO inference (single frame)
    results = model(frame, stream=True)  # stream=True yields results generator

    rects = []
    for result in results:
        for box in result.boxes:
            cls_id = int(box.cls[0])
            cls_name = model.names[cls_id]
            conf = float(box.conf[0])
            if cls_name != "person":
                continue
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            rects.append( (x1, y1, x2, y2) )

    # update tracker
    objects, bboxes = ct.update(rects)

    # draw counting line
    cv2.line(frame, (0, line_y), (W, line_y), (0, 0, 255), 2)

    # update trackable objects and counting logic
    for objectID, centroid in objects.items():
        to = trackableObjects.get(objectID, None)
        bbox = bboxes.get(objectID, None)
        if to is None:
            to = TrackableObject(objectID, centroid)
        else:
            to.centroids.append(centroid)

        # if not counted yet, check crossing
        if not to.counted and len(to.centroids) >= 2:
            prev_y = to.centroids[-2][1]
            cur_y = to.centroids[-1][1]

            # crossing downwards (above -> below)
            if prev_y < line_y and cur_y >= line_y:
                totalCount += 1
                to.counted = True
            # crossing upwards (below -> above) — count if you want both directions
            elif prev_y > line_y and cur_y <= line_y:
                totalCount += 1
                to.counted = True

        trackableObjects[objectID] = to

        # draw bbox or centroid + ID
        if bbox is not None:
            (x1, y1, x2, y2) = bbox
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"ID {objectID}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
        # draw centroid
        cv2.circle(frame, (centroid[0], centroid[1]), 4, (255, 0, 0), -1)

    # overlay total count
    cv2.putText(frame, f"Total: {totalCount}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 2)

    out.write(frame)

# cleanup
cap.release()
out.release()
cv2.destroyAllWindows()
end = time.time()
print(f"Processing done in {end-start:.1f}s. Saved -> {out_path}")


if os.path.exists(out_path):
    files.download(out_path)
else:
    print("❌ Output file not found.")
# Out:
# Loading YOLOv8 model (may take ~30s)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 69.3MB/s 0.1s
# Video opened: /content/853889-hd_1920_1080_25fps.mp4  (W,H) = (1920,1080), fps=25.0
#
# 0: 384x640 37 persons, 2 birds, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 3 birds, 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 birds, 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 3 birds, 9.5ms
# Speed: 3.4ms preprocess, 9.5ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 2 birds, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 9.4ms
# Speed: 3.8ms preprocess, 9.4ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 30.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 11.4ms
# Speed: 4.9ms preprocess, 11.4ms inference, 30.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 14.3ms
# Speed: 5.7ms preprocess, 14.3ms inference, 26.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 9.1ms
# Speed: 5.2ms preprocess, 9.1ms inference, 23.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 24.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 9.4ms
# Speed: 5.3ms preprocess, 9.4ms inference, 24.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 10.6ms
# Speed: 7.3ms preprocess, 10.6ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 9.4ms
# Speed: 4.6ms preprocess, 9.4ms inference, 22.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 15.6ms
# Speed: 3.3ms preprocess, 15.6ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 traffic light, 1 bird, 1 dog, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 24.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 21.1ms
# Speed: 7.3ms preprocess, 21.1ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 27.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 10.4ms
# Speed: 4.4ms preprocess, 10.4ms inference, 25.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 dog, 9.0ms
# Speed: 4.9ms preprocess, 9.0ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 1 dog, 8.7ms
# Speed: 3.4ms preprocess, 8.7ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 10.2ms
# Speed: 3.2ms preprocess, 10.2ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 8.6ms
# Speed: 5.0ms preprocess, 8.6ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 12.7ms
# Speed: 3.0ms preprocess, 12.7ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 14.6ms
# Speed: 2.9ms preprocess, 14.6ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 25.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 13.0ms
# Speed: 3.8ms preprocess, 13.0ms inference, 24.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 11.5ms
# Speed: 2.9ms preprocess, 11.5ms inference, 23.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 25.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 9.0ms
# Speed: 3.4ms preprocess, 9.0ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 3 birds, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 7.2ms
# Speed: 3.0ms preprocess, 7.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.0ms
# Speed: 3.2ms preprocess, 9.0ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 1 dog, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 1 dog, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 1 dog, 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 2 dogs, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 dog, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 33.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 8.9ms
# Speed: 3.2ms preprocess, 8.9ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 7.8ms
# Speed: 3.1ms preprocess, 7.8ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 dog, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 dog, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 9.1ms
# Speed: 3.1ms preprocess, 9.1ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 dog, 20.0ms
# Speed: 3.2ms preprocess, 20.0ms inference, 20.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 dog, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 1 dog, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 3 dogs, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 dog, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 8.2ms
# Speed: 2.9ms preprocess, 8.2ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 8.7ms
# Speed: 5.3ms preprocess, 8.7ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 7.8ms
# Speed: 3.1ms preprocess, 7.8ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 14.8ms
# Speed: 3.7ms preprocess, 14.8ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 3 birds, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 3 birds, 9.3ms
# Speed: 3.4ms preprocess, 9.3ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 7.8ms
# Speed: 4.4ms preprocess, 7.8ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.6ms
# Speed: 3.3ms preprocess, 9.6ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 9.6ms
# Speed: 3.6ms preprocess, 9.6ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 8.7ms
# Speed: 3.3ms preprocess, 8.7ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 6.4ms
# Speed: 3.1ms preprocess, 6.4ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 dog, 8.9ms
# Speed: 3.1ms preprocess, 8.9ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 backpack, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 dog, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 8.7ms
# Speed: 4.4ms preprocess, 8.7ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 1 handbag, 1 suitcase, 9.4ms
# Speed: 3.3ms preprocess, 9.4ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 1 suitcase, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 8.5ms
# Speed: 2.9ms preprocess, 8.5ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 suitcase, 9.0ms
# Speed: 3.9ms preprocess, 9.0ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 suitcase, 8.7ms
# Speed: 2.9ms preprocess, 8.7ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 dog, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 11.4ms
# Speed: 4.1ms preprocess, 11.4ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 dog, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 9.2ms
# Speed: 3.2ms preprocess, 9.2ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 10.0ms
# Speed: 3.4ms preprocess, 10.0ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 8.9ms
# Speed: 3.4ms preprocess, 8.9ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 9.2ms
# Speed: 4.8ms preprocess, 9.2ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 22.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 7.3ms
# Speed: 3.1ms preprocess, 7.3ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 suitcase, 9.0ms
# Speed: 2.9ms preprocess, 9.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 suitcase, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 suitcase, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 suitcase, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.8ms
# Speed: 5.4ms preprocess, 8.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 horse, 13.2ms
# Speed: 3.5ms preprocess, 13.2ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.8ms
# Speed: 3.1ms preprocess, 8.8ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 7.2ms
# Speed: 3.0ms preprocess, 7.2ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 7.5ms
# Speed: 3.1ms preprocess, 7.5ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.9ms
# Speed: 3.7ms preprocess, 9.9ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 8.5ms
# Speed: 2.9ms preprocess, 8.5ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 7.9ms
# Speed: 3.0ms preprocess, 7.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 6.3ms
# Speed: 3.1ms preprocess, 6.3ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 7.6ms
# Speed: 3.1ms preprocess, 7.6ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.7ms
# Speed: 2.9ms preprocess, 8.7ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 7.7ms
# Speed: 3.2ms preprocess, 7.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 7.6ms
# Speed: 2.9ms preprocess, 7.6ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 6.8ms
# Speed: 3.2ms preprocess, 6.8ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 9.2ms
# Speed: 7.1ms preprocess, 9.2ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.8ms
# Speed: 3.5ms preprocess, 8.8ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 6.6ms
# Speed: 3.2ms preprocess, 6.6ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 8.9ms
# Speed: 3.2ms preprocess, 8.9ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 6.9ms
# Speed: 3.3ms preprocess, 6.9ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 skis, 8.1ms
# Speed: 3.3ms preprocess, 8.1ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 skis, 6.9ms
# Speed: 3.5ms preprocess, 6.9ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 7.3ms
# Speed: 4.1ms preprocess, 7.3ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 backpack, 9.8ms
# Speed: 3.3ms preprocess, 9.8ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 handbag, 8.1ms
# Speed: 3.4ms preprocess, 8.1ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 handbag, 9.3ms
# Speed: 3.4ms preprocess, 9.3ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 dog, 17.4ms
# Speed: 3.1ms preprocess, 17.4ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 10.1ms
# Speed: 10.9ms preprocess, 10.1ms inference, 22.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 motorcycle, 1 handbag, 11.3ms
# Speed: 3.2ms preprocess, 11.3ms inference, 22.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 7.8ms
# Speed: 3.4ms preprocess, 7.8ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 motorcycle, 1 handbag, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 23.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 horse, 1 handbag, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 20.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 motorcycles, 1 horse, 1 handbag, 8.8ms
# Speed: 3.7ms preprocess, 8.8ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 horse, 1 backpack, 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 13.0ms
# Speed: 8.6ms preprocess, 13.0ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 motorcycle, 13.1ms
# Speed: 3.3ms preprocess, 13.1ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 motorcycle, 1 dog, 10.1ms
# Speed: 3.5ms preprocess, 10.1ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 1 backpack, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 18.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 motorcycle, 1 backpack, 19.5ms
# Speed: 3.3ms preprocess, 19.5ms inference, 24.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 11.7ms
# Speed: 3.3ms preprocess, 11.7ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 7.7ms
# Speed: 4.9ms preprocess, 7.7ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 1 backpack, 1 handbag, 14.3ms
# Speed: 3.4ms preprocess, 14.3ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 10.8ms
# Speed: 5.0ms preprocess, 10.8ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 8.1ms
# Speed: 6.2ms preprocess, 8.1ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 22.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 16.0ms
# Speed: 3.2ms preprocess, 16.0ms inference, 19.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 11.3ms
# Speed: 3.1ms preprocess, 11.3ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 skis, 12.1ms
# Speed: 3.3ms preprocess, 12.1ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 skis, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 bird, 1 skis, 19.2ms
# Speed: 3.2ms preprocess, 19.2ms inference, 31.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 1 horse, 1 handbag, 1 skis, 13.7ms
# Speed: 6.3ms preprocess, 13.7ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 1 handbag, 1 skis, 8.2ms
# Speed: 3.2ms preprocess, 8.2ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 1 skis, 11.8ms
# Speed: 5.2ms preprocess, 11.8ms inference, 25.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 17.4ms
# Speed: 3.2ms preprocess, 17.4ms inference, 22.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 11.3ms
# Speed: 6.1ms preprocess, 11.3ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 7.7ms
# Speed: 3.2ms preprocess, 7.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 horse, 1 backpack, 1 handbag, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 9.1ms
# Speed: 3.5ms preprocess, 9.1ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 dogs, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 6.7ms
# Speed: 3.5ms preprocess, 6.7ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 dog, 1 handbag, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 dog, 1 backpack, 17.7ms
# Speed: 3.1ms preprocess, 17.7ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 9.5ms
# Speed: 3.4ms preprocess, 9.5ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 handbag, 8.4ms
# Speed: 3.5ms preprocess, 8.4ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 9.7ms
# Speed: 4.2ms preprocess, 9.7ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 1 handbag, 9.9ms
# Speed: 3.8ms preprocess, 9.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 motorcycle, 1 handbag, 7.7ms
# Speed: 3.6ms preprocess, 7.7ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 motorcycle, 1 bird, 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 motorcycle, 1 handbag, 9.5ms
# Speed: 4.6ms preprocess, 9.5ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 birds, 1 handbag, 9.7ms
# Speed: 4.0ms preprocess, 9.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 birds, 1 dog, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 birds, 1 dog, 1 handbag, 8.9ms
# Speed: 3.8ms preprocess, 8.9ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 handbag, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 7.8ms
# Speed: 3.3ms preprocess, 7.8ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 1 handbag, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.5ms
# Speed: 3.8ms preprocess, 9.5ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.8ms
# Speed: 4.2ms preprocess, 8.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 backpack, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 8.0ms
# Speed: 3.4ms preprocess, 8.0ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 6.9ms
# Speed: 3.4ms preprocess, 6.9ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 8.1ms
# Speed: 3.4ms preprocess, 8.1ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 birds, 1 handbag, 9.2ms
# Speed: 3.1ms preprocess, 9.2ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 handbag, 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 9.5ms
# Speed: 4.2ms preprocess, 9.5ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 handbag, 9.2ms
# Speed: 3.1ms preprocess, 9.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 handbag, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 7.2ms
# Speed: 3.0ms preprocess, 7.2ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 backpack, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 23.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 7.7ms
# Speed: 3.2ms preprocess, 7.7ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 handbag, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 9.9ms
# Speed: 3.9ms preprocess, 9.9ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 handbags, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 handbags, 9.1ms
# Speed: 3.1ms preprocess, 9.1ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 handbag, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 dog, 1 handbag, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 9.2ms
# Speed: 3.2ms preprocess, 9.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 dog, 1 backpack, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 2 backpacks, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 23.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 8.7ms
# Speed: 4.1ms preprocess, 8.7ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.1ms
# Speed: 4.5ms preprocess, 9.1ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 8.2ms
# Speed: 2.9ms preprocess, 8.2ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 backpack, 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 1 backpack, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 1 dog, 1 backpack, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 8.0ms
# Speed: 3.3ms preprocess, 8.0ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 8.8ms
# Speed: 3.4ms preprocess, 8.8ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 umbrella, 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 22.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 1 umbrella, 7.1ms
# Speed: 3.9ms preprocess, 7.1ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 dogs, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 dog, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 9.1ms
# Speed: 4.8ms preprocess, 9.1ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 8.9ms
# Speed: 3.7ms preprocess, 8.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 dog, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 umbrella, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 9.1ms
# Speed: 3.1ms preprocess, 9.1ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 7.1ms
# Speed: 3.0ms preprocess, 7.1ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 9.7ms
# Speed: 4.9ms preprocess, 9.7ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.8ms
# Speed: 4.1ms preprocess, 8.8ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 dog, 10.0ms
# Speed: 4.8ms preprocess, 10.0ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 8.8ms
# Speed: 3.1ms preprocess, 8.8ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 9.6ms
# Speed: 4.8ms preprocess, 9.6ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 7.4ms
# Speed: 3.1ms preprocess, 7.4ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 6.6ms
# Speed: 3.0ms preprocess, 6.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 6.5ms
# Speed: 3.2ms preprocess, 6.5ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 7.3ms
# Speed: 3.3ms preprocess, 7.3ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing done in 22.6s. Saved -> people_counting.mp4
